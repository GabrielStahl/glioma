# %%
from __future__ import print_function
import sys
import os
import six
from radiomics import featureextractor, getFeatureClasses
import radiomics
import SimpleITK as sitk
import pandas as pd
import traceback
from scipy.stats import pearsonr
import numpy as np

# Configure Settings
dataset = "training" # Choose from: ["training", "validation", "test"] -- this will determine which dataset to use
Filter = "SquareRoot" # Choose from: ["Original", "SquareRoot", "Wavelet", "Square", "Exponential", "Logarithm"]
#Filter = sys.argv[1] # Pass the filter as an argument in the bash file
Store_Original = False # Choose from: [True, False] 
# choose modalities from: ["T1","T2","DTI_eddy_FA", "FLAIR", "SWI", "DWI", "T1_contrast", "DTI_eddy_MD", "ADC", "ASL"]
acquisitions = ["T1","T2","DTI_eddy_FA", "FLAIR", "SWI", "DWI", "T1_contrast", "DTI_eddy_MD", "ADC", "ASL"] 

def get_settings():
    environment = os.environ.get('PYRADIOMICS_ENV', 'local')  # Default to 'local' if the environment variable is not set

    if environment == 'local':
        base_dir = "/Users/Gabriel/Desktop/MSc_Dissertation/pyRadiomics/Data/"
        params = "/Users/Gabriel/Desktop/MSc_Dissertation/pyRadiomics/Params.yaml"
        train_df = pd.read_csv("/Users/Gabriel/Desktop/MSc_Dissertation/pyRadiomics/Training/" + dataset + "_data.csv") 
    elif environment == 'cluster':
        base_dir = "/cluster/project2/UCSF_PDGM_dataset/UCSF-PDGM-v3/"
        params = "/home/goliveir/pyRadiomics/Params.yaml"
        train_df = pd.read_csv("/home/goliveir/pyRadiomics/" + dataset + "_data.csv") 
    else:
        raise ValueError("Unknown environment: please set PYRADIOMICS_ENV to 'local' or 'cluster'")

    return base_dir, params, train_df, environment

def read_image_and_label(image_path, label_path, patient_id):
    Image = sitk.ReadImage(image_path)
    Label = sitk.ReadImage(label_path)

    if Image is None or Label is None:
        raise Exception(f"Error getting data for patient {patient_id}!")

    return Image, Label

def extract_features(params, Image, Label, patient_id):
    try:
        extractor = featureextractor.RadiomicsFeatureExtractor(params)
        result = extractor.execute(Image, Label)  
        return extractor, result
    except Exception as e:
        print(f"Could not extract features for patient {patient_id} Reason: {str(e)} \nretrying with label-value=2")
        settings = {'label': 2}
        extractor = radiomics.featureextractor.RadiomicsFeatureExtractor(additionalInfo=True, **settings)
        result = extractor.execute(Image, Label)  
        return extractor, result
    

def apply_filters_on_images(extractor):

    # By default, only 'Original' (no filter applied) is enabled. Optionally enable some image types:

    filter_types = {
        "SquareRoot": 'SquareRoot',
        "Wavelet": 'Wavelet',
        "LoG": 'LoG',
        "Square": 'Square',
        "Exponential": 'Exponential',
        "Logarithm": 'Logarithm'
    }

    for filter_type, filter_name in filter_types.items():
        if Filter == filter_type:
            extractor.enableImageTypeByName(filter_name)
    
    print('Filters applied on the image:')
    for imageType in extractor.enabledImagetypes.keys():
        print('\t' + imageType)

    return extractor

def calculate_features(extractor, Image, Label):
    extractor.disableAllFeatures() # These 2 lines will cause only firstorder features to be calculated
    extractor.enableFeatureClassByName('firstorder') 
    featureVector = extractor.execute(Image, Label)
    
    # Show calculated features
    print('Calculated features:')
    for featureName in featureVector.keys():
        print('Computed %s: %s' % (featureName, featureVector[featureName]))
    return featureVector

def fetch_data(base_dir, patient_id, img_type):
    folder_name = f"UCSF-PDGM-{patient_id:04d}_nifti"
    data_dir = os.path.join(base_dir, folder_name)
    
    image_types = {
        "DTI_eddy_FA": "_DTI_eddy_FA.nii.gz",
        "FLAIR": "_FLAIR_bias.nii.gz",
        "SWI": "_SWI.nii.gz",
        "T1": "_T1_bias.nii.gz",
        "T2": "_T2_bias.nii.gz",
        "DWI": "_DWI_bias.nii.gz",
        "T1_contrast": "_T1c_bias.nii.gz",
        "DTI_eddy_MD": "_DTI_eddy_MD.nii.gz",
        "ADC": "_ADC.nii.gz",
        "ASL": "_ASL.nii.gz"
    } 
    
    if img_type in image_types:
        print(f"Processing {img_type} image for patient {patient_id}")
        image_filename = f"UCSF-PDGM-{patient_id:04d}{image_types[img_type]}"
        image_path = os.path.join(data_dir, image_filename)
    else:
        print(f"Unknown image type: {img_type}")
        image_path = None
    
    label_filename = f"UCSF-PDGM-{patient_id:04d}_tumor_segmentation.nii.gz"
    label_path = os.path.join(data_dir, label_filename)
    
    return image_path, label_path
    
def main():
    base_dir, params, train_df, environment = get_settings()
    lost_patients = []
    
    for cImg in acquisitions:
        img_type = cImg 
        
        feature_data = pd.DataFrame() # Initialize feature data df
        feature_data_sqrroot = pd.DataFrame() # Initialize feature data df
        feature_data_wavelet = pd.DataFrame() # Initialize feature data df
        feature_data_log = pd.DataFrame() # Initialize feature data df
        feature_data_square = pd.DataFrame() # Initialize feature data df
        feature_data_exponential = pd.DataFrame() # Initialize feature data df
        feature_data_logarithm = pd.DataFrame() # Initialize feature data df

        errors_id = pd.DataFrame()
        count = 0

        for _, row in train_df.iterrows():
            patient_id_str = row[0]  # Assuming the patient ID is in the first column
            patient_id = int(patient_id_str.split("-")[-1])
            image_path, label_path = fetch_data(base_dir, patient_id, img_type)

            try:
                Image, Label = read_image_and_label(image_path, label_path, patient_id)
                extractor, result = extract_features(params, Image, Label, patient_id) # Here it goes wrong if label < 3
                extractor = apply_filters_on_images(extractor)
                featureVector = calculate_features(extractor, Image, Label)
                
                # Always store the original features in the feature_data DataFrame
                original_features = {key: value for key, value in featureVector.items() if key.startswith('original_firstorder_')}
                feature_data = feature_data.append(pd.DataFrame(original_features, index=[patient_id]))

                # Additionally, store the filtered features in separate DataFrames
                if Filter == "SquareRoot":
                    sqrroot_features = {key: value for key, value in featureVector.items() if key.startswith('squareroot_firstorder_')}
                    print("Findme",sqrroot_features)
                    feature_data_sqrroot = feature_data_sqrroot.append(pd.DataFrame(sqrroot_features, index=[patient_id]))

                if Filter == "Wavelet":
                    wavelet_features = {key: value for key, value in featureVector.items() if key.startswith('wavelet-LLH_firstorder_')}
                    feature_data_wavelet = feature_data_wavelet.append(pd.DataFrame(wavelet_features, index=[patient_id]))

                if Filter == "LoG":
                    log_features = {key: value for key, value in featureVector.items() if key.startswith('logarithm_firstorder_')}
                    feature_data_log = feature_data_log.append(pd.DataFrame(log_features, index=[patient_id]))

                if Filter == "Square":
                    square_features = {key: value for key, value in featureVector.items() if key.startswith('square_firstorder_')}
                    feature_data_square = feature_data_square.append(pd.DataFrame(square_features, index=[patient_id]))

                if Filter == "Exponential":
                    exponential_features = {key: value for key, value in featureVector.items() if key.startswith('exponential_firstorder_')}
                    feature_data_exponential = feature_data_exponential.append(pd.DataFrame(exponential_features, index=[patient_id]))

                if Filter == "Logarithm":
                    logarithm_features = {key: value for key, value in featureVector.items() if key.startswith('logarithm_firstorder_')}
                    feature_data_logarithm = feature_data_logarithm.append(pd.DataFrame(logarithm_features, index=[patient_id]))
    
            except Exception as e:
                count += 1
                tb_str = traceback.format_exception(etype=type(e), value=e, tb=e.__traceback__)
                tb_str = ''.join(tb_str)
                #print(f"Error for patient {patient_id}: {str(e)}\nTraceback:\n{tb_str}")
                lost_patients.append(patient_id)

        print(f'Number of errors occurred: {count} --> patients affected by error {set(lost_patients)}')
        
        # Save the feature_data DataFrame as a CSV file in the base_dir
        if Store_Original == True:
            feature_data.to_csv(os.path.join(base_dir, f"{dataset}_firstorder_original_{img_type}.csv"))    

        if Filter == "SquareRoot":
            feature_data_sqrroot.to_csv(os.path.join(base_dir, f"{dataset}_firstorder_sqrroot_{img_type}.csv"))

        if Filter == "Wavelet":
            feature_data_wavelet.to_csv(os.path.join(base_dir, f"{dataset}_firstorder_wavelet_{img_type}.csv"))
        
        if Filter == "Square":
            feature_data_square.to_csv(os.path.join(base_dir, f"{dataset}_firstorder_square_{img_type}.csv"))
        
        if Filter == "Exponential":
            feature_data_exponential.to_csv(os.path.join(base_dir, f"{dataset}_firstorder_exponential_{img_type}.csv"))
        
        if Filter == "Logarithm":
            feature_data_logarithm.to_csv(os.path.join(base_dir, f"{dataset}_firstorder_logarithm_{img_type}.csv"))
            
        
if __name__ == "__main__":
    main()
# Out:
# Processing T1 image for patient 491
# Processing T1 image for patient 121
# Processing T1 image for patient 93
# Processing T1 image for patient 183
# Processing T1 image for patient 421
# Processing T1 image for patient 295
# Processing T1 image for patient 355
# Processing T1 image for patient 390
# Processing T1 image for patient 145
# Processing T1 image for patient 197
# Processing T1 image for patient 173
# Processing T1 image for patient 108
# Processing T1 image for patient 325
# Processing T1 image for patient 191
# Processing T1 image for patient 367
# Processing T1 image for patient 453
# Processing T1 image for patient 234
# Processing T1 image for patient 412
# Processing T1 image for patient 370
# Processing T1 image for patient 381
# Processing T1 image for patient 510
# Processing T1 image for patient 71
# Processing T1 image for patient 112
# Processing T1 image for patient 330
# Processing T1 image for patient 264
# Processing T1 image for patient 276
# Processing T1 image for patient 179
# Processing T1 image for patient 374
# Processing T1 image for patient 131
# Processing T1 image for patient 223
# Processing T1 image for patient 208
# Processing T1 image for patient 23
# Processing T1 image for patient 229
# Processing T1 image for patient 156
# Processing T1 image for patient 198
# Processing T1 image for patient 18
# Processing T1 image for patient 539
# Processing T1 image for patient 205
# Processing T1 image for patient 236
# Processing T1 image for patient 26
# Processing T1 image for patient 103
# Processing T1 image for patient 279
# Processing T1 image for patient 372
# Processing T1 image for patient 69
# Processing T1 image for patient 474
# Processing T1 image for patient 237
# Processing T1 image for patient 250
# Processing T1 image for patient 31
# Processing T1 image for patient 454
# Processing T1 image for patient 534
# Processing T1 image for patient 142
# Processing T1 image for patient 516
# Processing T1 image for patient 45
# Processing T1 image for patient 298
# Processing T1 image for patient 240
# Processing T1 image for patient 123
# Processing T1 image for patient 382
# Processing T1 image for patient 525
# Processing T1 image for patient 306
# Processing T1 image for patient 102
# Processing T1 image for patient 422
# Processing T1 image for patient 86
# Processing T1 image for patient 166
# Processing T1 image for patient 297
# Processing T1 image for patient 243
# Processing T1 image for patient 464
# Processing T1 image for patient 375
# Processing T1 image for patient 426
# Processing T1 image for patient 358
# Processing T1 image for patient 104
# Processing T1 image for patient 448
# Processing T1 image for patient 8
# Processing T1 image for patient 66
# Processing T1 image for patient 270
# Processing T1 image for patient 128
# Processing T1 image for patient 541
# Processing T1 image for patient 457
# Processing T1 image for patient 538
# Processing T1 image for patient 75
# Processing T1 image for patient 456
# Processing T1 image for patient 353
# Processing T1 image for patient 13
# Processing T1 image for patient 99
# Processing T1 image for patient 481
# Processing T1 image for patient 465
# Processing T1 image for patient 160
# Processing T1 image for patient 495
# Processing T1 image for patient 251
# Processing T1 image for patient 455
# Processing T1 image for patient 24
# Processing T1 image for patient 509
# Processing T1 image for patient 494
# Processing T1 image for patient 530
# Processing T1 image for patient 405
# Processing T1 image for patient 524
# Processing T1 image for patient 176
# Processing T1 image for patient 116
# Processing T1 image for patient 68
# Processing T1 image for patient 137
# Processing T1 image for patient 537
# Processing T1 image for patient 88
# Processing T1 image for patient 12
# Processing T1 image for patient 190
# Processing T1 image for patient 20
# Processing T1 image for patient 480
# Processing T1 image for patient 307
# Processing T1 image for patient 468
# Processing T1 image for patient 458
# Processing T1 image for patient 119
# Processing T1 image for patient 186
# Processing T1 image for patient 30
# Processing T1 image for patient 70
# Processing T1 image for patient 135
# Processing T1 image for patient 407
# Processing T1 image for patient 346
# Processing T1 image for patient 461
# Processing T1 image for patient 238
# Processing T1 image for patient 201
# Processing T1 image for patient 423
# Processing T1 image for patient 506
# Processing T1 image for patient 106
# Processing T1 image for patient 514
# Processing T1 image for patient 532
# Processing T1 image for patient 126
# Processing T1 image for patient 356
# Processing T1 image for patient 433
# Processing T1 image for patient 338
# Processing T1 image for patient 368
# Processing T1 image for patient 228
# Processing T1 image for patient 384
# Processing T1 image for patient 78
# Processing T1 image for patient 489
# Processing T1 image for patient 310
# Processing T1 image for patient 520
# Processing T1 image for patient 527
# Processing T1 image for patient 287
# Processing T1 image for patient 233
# Processing T1 image for patient 389
# Processing T1 image for patient 467
# Processing T1 image for patient 436
# Processing T1 image for patient 35
# Processing T1 image for patient 29
# Processing T1 image for patient 515
# Processing T1 image for patient 273
# Processing T1 image for patient 65
# Processing T1 image for patient 318
# Processing T1 image for patient 154
# Processing T1 image for patient 449
# Processing T1 image for patient 151
# Processing T1 image for patient 95
# Processing T1 image for patient 227
# Processing T1 image for patient 111
# Processing T1 image for patient 272
# Processing T1 image for patient 141
# Processing T1 image for patient 362
# Processing T1 image for patient 476
# Processing T1 image for patient 245
# Processing T1 image for patient 460
# Processing T1 image for patient 247
# Processing T1 image for patient 499
# Processing T1 image for patient 396
# Processing T1 image for patient 83
# Processing T1 image for patient 445
# Processing T1 image for patient 415
# Processing T1 image for patient 58
# Processing T1 image for patient 209
# Processing T1 image for patient 164
# Processing T1 image for patient 371
# Processing T1 image for patient 483
# Processing T1 image for patient 10
# Processing T1 image for patient 77
# Processing T1 image for patient 359
# Processing T1 image for patient 435
# Processing T1 image for patient 477
# Processing T1 image for patient 231
# Processing T1 image for patient 206
# Processing T1 image for patient 89
# Processing T1 image for patient 406
# Processing T1 image for patient 424
# Processing T1 image for patient 517
# Processing T1 image for patient 512
# Processing T1 image for patient 200
# Processing T1 image for patient 261
# Processing T1 image for patient 440
# Could not extract features for patient 440 Reason: Label (1) not present in mask. Choose from [2]
# retrying with label-value=2
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Filters applied on the image:
# 	Original
# 	SquareRoot
# Calculated features:
# Computed diagnostics_Versions_PyRadiomics: v3.0.1
# Computed diagnostics_Versions_Numpy: 1.21.6
# Computed diagnostics_Versions_SimpleITK: 2.2.1
# Computed diagnostics_Versions_PyWavelet: 1.3.0
# Computed diagnostics_Versions_Python: 3.7.0
# Computed diagnostics_Configuration_Settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 2, 'additionalInfo': True}
# Computed diagnostics_Configuration_EnabledImageTypes: {'Original': {}, 'SquareRoot': {}}
# Computed diagnostics_Image-original_Hash: a7682d690399467eb127e09cf2713987f6fe4285
# Computed diagnostics_Image-original_Dimensionality: 3D
# Computed diagnostics_Image-original_Spacing: (1.0, 1.0, 1.0)
# Computed diagnostics_Image-original_Size: (240, 240, 155)
# Computed diagnostics_Image-original_Mean: 480.71568295534536
# Computed diagnostics_Image-original_Minimum: 0.0
# Computed diagnostics_Image-original_Maximum: 4892.53125
# Computed diagnostics_Mask-original_Hash: 8a6caa6d7e72516b16957a57d619a0d249719714
# Computed diagnostics_Mask-original_Spacing: (1.0, 1.0, 1.0)
# Computed diagnostics_Mask-original_Size: (240, 240, 155)
# Computed diagnostics_Mask-original_BoundingBox: (50, 33, 41, 79, 148, 75)
# Computed diagnostics_Mask-original_VoxelNum: 261985
# Computed diagnostics_Mask-original_VolumeNum: 2
# Computed diagnostics_Mask-original_CenterOfMassIndex: (87.73580548504685, 119.97307861137088, 80.49262744050232)
# Computed diagnostics_Mask-original_CenterOfMass: (87.73580548504685, -119.02692138862912, 80.49262744050232)
# Computed original_firstorder_10Percentile: 1985.4113525390626
# Computed original_firstorder_90Percentile: 3148.062255859375
# Computed original_firstorder_Energy: 1731209842530.9175
# Computed original_firstorder_Entropy: 6.21817302141538
# Computed original_firstorder_InterquartileRange: 596.495361328125
# Computed original_firstorder_Kurtosis: 3.1409238258879033
# Computed original_firstorder_Maximum: 4389.05615234375
# Computed original_firstorder_MeanAbsoluteDeviation: 361.60599066698967
# Computed original_firstorder_Mean: 2529.7508598659183
# Computed original_firstorder_Median: 2490.722900390625
# Computed original_firstorder_Minimum: 568.350341796875
# Computed original_firstorder_Range: 3820.705810546875
# Computed original_firstorder_RobustMeanAbsoluteDeviation: 249.38115664486023
# Computed original_firstorder_RootMeanSquared: 2570.6126659109036
# Computed original_firstorder_Skewness: 0.3233717121074653
# Computed original_firstorder_TotalEnergy: 1731209842530.9175
# Computed original_firstorder_Uniformity: 0.015926663699568487
# Computed original_firstorder_Variance: 208410.0651492074
# Computed squareroot_firstorder_10Percentile: 3116.6788550598117
# Computed squareroot_firstorder_90Percentile: 3924.537292947729
# Computed squareroot_firstorder_Energy: 3242558252514.3457
# Computed squareroot_firstorder_Entropy: 5.70626068355113
# Computed squareroot_firstorder_InterquartileRange: 416.7068389252845
# Computed squareroot_firstorder_Kurtosis: 3.1727633136145994
# Computed squareroot_firstorder_Maximum: 4633.960982069935
# Computed squareroot_firstorder_MeanAbsoluteDeviation: 251.37386566152642
# Computed squareroot_firstorder_Mean: 3503.721689059046
# Computed squareroot_firstorder_Median: 3490.8365222753946
# Computed squareroot_firstorder_Minimum: 1667.5346497717499
# Computed squareroot_firstorder_Range: 2966.426332298185
# Computed squareroot_firstorder_RobustMeanAbsoluteDeviation: 173.73783524282118
# Computed squareroot_firstorder_RootMeanSquared: 3518.079751314398
# Computed squareroot_firstorder_Skewness: 0.035512050217197284
# Computed squareroot_firstorder_TotalEnergy: 3242558252514.3457
# Computed squareroot_firstorder_Uniformity: 0.022619256122367423
# Computed squareroot_firstorder_Variance: 100819.46222560374
# Findme {'squareroot_firstorder_10Percentile': array(3116.67885506), 'squareroot_firstorder_90Percentile': array(3924.53729295), 'squareroot_firstorder_Energy': array(3.24255825e+12), 'squareroot_firstorder_Entropy': array(5.70626068), 'squareroot_firstorder_InterquartileRange': array(416.70683893), 'squareroot_firstorder_Kurtosis': array(3.17276331), 'squareroot_firstorder_Maximum': array(4633.96098207), 'squareroot_firstorder_MeanAbsoluteDeviation': array(251.37386566), 'squareroot_firstorder_Mean': array(3503.72168906), 'squareroot_firstorder_Median': array(3490.83652228), 'squareroot_firstorder_Minimum': array(1667.53464977), 'squareroot_firstorder_Range': array(2966.4263323), 'squareroot_firstorder_RobustMeanAbsoluteDeviation': array(173.73783524), 'squareroot_firstorder_RootMeanSquared': array(3518.07975131), 'squareroot_firstorder_Skewness': array(0.03551205), 'squareroot_firstorder_TotalEnergy': array(3.24255825e+12), 'squareroot_firstorder_Uniformity': array(0.02261926), 'squareroot_firstorder_Variance': array(100819.4622256)}
# Processing T1 image for patient 118
# Processing T1 image for patient 282
# Processing T1 image for patient 252
# Processing T1 image for patient 409
# Processing T1 image for patient 490
# Processing T1 image for patient 378
# Processing T1 image for patient 402
# Processing T1 image for patient 357
# Processing T1 image for patient 134
# Processing T1 image for patient 300
# Processing T1 image for patient 91
# Processing T1 image for patient 416
# Processing T1 image for patient 452
# Processing T1 image for patient 475
# Processing T1 image for patient 469
# Processing T1 image for patient 246
# Processing T1 image for patient 347
# Processing T1 image for patient 39
# Processing T1 image for patient 290
# Processing T1 image for patient 174
# Processing T1 image for patient 403
# Processing T1 image for patient 11
# Processing T1 image for patient 528
# Processing T1 image for patient 471
# Processing T1 image for patient 441
# Processing T1 image for patient 364
# Processing T1 image for patient 16
# Processing T1 image for patient 105
# Processing T1 image for patient 479
# Processing T1 image for patient 312
# Processing T1 image for patient 178
# Processing T1 image for patient 127
# Processing T1 image for patient 340
# Processing T1 image for patient 94
# Processing T1 image for patient 425
# Processing T1 image for patient 444
# Processing T1 image for patient 388
# Processing T1 image for patient 529
# Processing T1 image for patient 286
# Processing T1 image for patient 484
# Processing T1 image for patient 349
# Processing T1 image for patient 418
# Processing T1 image for patient 373
# Processing T1 image for patient 526
# Processing T1 image for patient 383
# Processing T1 image for patient 87
# Processing T1 image for patient 314
# Processing T1 image for patient 265
# Processing T1 image for patient 225
# Processing T1 image for patient 4
# Processing T1 image for patient 420
# Processing T1 image for patient 387
# Processing T1 image for patient 399
# Processing T1 image for patient 508
# Processing T1 image for patient 253
# Processing T1 image for patient 284
# Processing T1 image for patient 432
# Processing T1 image for patient 187
# Processing T1 image for patient 336
# Processing T1 image for patient 319
# Processing T1 image for patient 513
# Processing T1 image for patient 158
# Processing T1 image for patient 302
# Processing T1 image for patient 14
# Processing T1 image for patient 274
# Processing T1 image for patient 132
# Processing T1 image for patient 148
# Processing T1 image for patient 27
# Processing T1 image for patient 400
# Processing T1 image for patient 281
# Processing T1 image for patient 331
# Processing T1 image for patient 451
# Processing T1 image for patient 501
# Processing T1 image for patient 266
# Processing T1 image for patient 96
# Processing T1 image for patient 144
# Processing T1 image for patient 64
# Processing T1 image for patient 332
# Processing T1 image for patient 344
# Processing T1 image for patient 462
# Processing T1 image for patient 67
# Processing T1 image for patient 419
# Processing T1 image for patient 518
# Processing T1 image for patient 43
# Processing T1 image for patient 360
# Processing T1 image for patient 169
# Processing T1 image for patient 260
# Processing T1 image for patient 323
# Processing T1 image for patient 317
# Processing T1 image for patient 79
# Processing T1 image for patient 334
# Processing T1 image for patient 350
# Processing T1 image for patient 232
# Processing T1 image for patient 74
# Processing T1 image for patient 268
# Processing T1 image for patient 466
# Processing T1 image for patient 48
# Processing T1 image for patient 170
# Processing T1 image for patient 188
# Processing T1 image for patient 55
# Processing T1 image for patient 84
# Processing T1 image for patient 42
# Processing T1 image for patient 165
# Processing T1 image for patient 288
# Processing T1 image for patient 114
# Processing T1 image for patient 207
# Processing T1 image for patient 411
# Processing T1 image for patient 380
# Processing T1 image for patient 21
# Processing T1 image for patient 500
# Processing T1 image for patient 214
# Processing T1 image for patient 184
# Processing T1 image for patient 430
# Processing T1 image for patient 157
# Processing T1 image for patient 143
# Processing T1 image for patient 379
# Processing T1 image for patient 485
# Processing T1 image for patient 256
# Processing T1 image for patient 459
# Processing T1 image for patient 414
# Processing T1 image for patient 413
# Processing T1 image for patient 470
# Processing T1 image for patient 434
# Processing T1 image for patient 337
# Processing T1 image for patient 107
# Processing T1 image for patient 308
# Processing T1 image for patient 329
# Processing T1 image for patient 519
# Processing T1 image for patient 277
# Processing T1 image for patient 446
# Processing T1 image for patient 44
# Processing T1 image for patient 189
# Processing T1 image for patient 167
# Processing T1 image for patient 22
# Processing T1 image for patient 428
# Processing T1 image for patient 493
# Processing T1 image for patient 140
# Processing T1 image for patient 101
# Processing T1 image for patient 386
# Processing T1 image for patient 377
# Processing T1 image for patient 80
# Processing T1 image for patient 438
# Processing T1 image for patient 213
# Processing T1 image for patient 168
# Processing T1 image for patient 258
# Processing T1 image for patient 473
# Processing T1 image for patient 431
# Processing T1 image for patient 429
# Processing T1 image for patient 535
# Processing T1 image for patient 242
# Processing T1 image for patient 63
# Processing T1 image for patient 303
# Processing T1 image for patient 82
# Processing T1 image for patient 352
# Processing T1 image for patient 196
# Processing T1 image for patient 505
# Processing T1 image for patient 385
# Processing T1 image for patient 32
# Processing T1 image for patient 326
# Processing T1 image for patient 522
# Processing T1 image for patient 417
# Processing T1 image for patient 404
# Processing T1 image for patient 442
# Processing T1 image for patient 503
# Processing T1 image for patient 147
# Processing T1 image for patient 342
# Processing T1 image for patient 90
# Processing T1 image for patient 365
# Processing T1 image for patient 136
# Processing T1 image for patient 25
# Processing T1 image for patient 162
# Processing T1 image for patient 410
# Processing T1 image for patient 163
# Processing T1 image for patient 305
# Processing T1 image for patient 283
# Processing T1 image for patient 59
# Processing T1 image for patient 439
# Processing T1 image for patient 398
# Processing T1 image for patient 487
# Processing T1 image for patient 348
# Processing T1 image for patient 202
# Processing T1 image for patient 7
# Processing T1 image for patient 269
# Processing T1 image for patient 150
# Processing T1 image for patient 511
# Processing T1 image for patient 37
# Processing T1 image for patient 309
# Processing T1 image for patient 393
# Processing T1 image for patient 180
# Processing T1 image for patient 53
# Processing T1 image for patient 296
# Processing T1 image for patient 354
# Processing T1 image for patient 5
# Processing T1 image for patient 437
# Processing T1 image for patient 36
# Processing T1 image for patient 341
# Processing T1 image for patient 321
# Processing T1 image for patient 395
# Processing T1 image for patient 85
# Processing T1 image for patient 204
# Processing T1 image for patient 122
# Processing T1 image for patient 210
# Processing T1 image for patient 15
# Processing T1 image for patient 129
# Processing T1 image for patient 504
# Processing T1 image for patient 327
# Processing T1 image for patient 492
# Processing T1 image for patient 57
# Processing T1 image for patient 130
# Processing T1 image for patient 172
# Processing T1 image for patient 159
# Processing T1 image for patient 235
# Number of errors occurred: 395 --> patients affected by error {4, 5, 7, 8, 10, 11, 12, 13, 14, 15, 16, 18, 20, 21, 22, 23, 24, 25, 26, 27, 29, 30, 31, 32, 35, 36, 37, 39, 42, 43, 44, 45, 48, 53, 55, 57, 58, 59, 63, 64, 65, 66, 67, 68, 69, 70, 71, 74, 75, 77, 78, 79, 80, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 93, 94, 95, 96, 99, 101, 102, 103, 104, 105, 106, 107, 108, 111, 112, 114, 116, 118, 119, 121, 122, 123, 126, 127, 128, 129, 130, 131, 132, 134, 135, 136, 137, 140, 141, 142, 143, 144, 145, 147, 148, 150, 151, 154, 156, 157, 158, 159, 160, 162, 163, 164, 165, 166, 167, 168, 169, 170, 172, 173, 174, 176, 178, 179, 180, 183, 184, 186, 187, 188, 189, 190, 191, 196, 197, 198, 200, 201, 202, 204, 205, 206, 207, 208, 209, 210, 213, 214, 223, 225, 227, 228, 229, 231, 232, 233, 234, 235, 236, 237, 238, 240, 242, 243, 245, 246, 247, 250, 251, 252, 253, 256, 258, 260, 261, 264, 265, 266, 268, 269, 270, 272, 273, 274, 276, 277, 279, 281, 282, 283, 284, 286, 287, 288, 290, 295, 296, 297, 298, 300, 302, 303, 305, 306, 307, 308, 309, 310, 312, 314, 317, 318, 319, 321, 323, 325, 326, 327, 329, 330, 331, 332, 334, 336, 337, 338, 340, 341, 342, 344, 346, 347, 348, 349, 350, 352, 353, 354, 355, 356, 357, 358, 359, 360, 362, 364, 365, 367, 368, 370, 371, 372, 373, 374, 375, 377, 378, 379, 380, 381, 382, 383, 384, 385, 386, 387, 388, 389, 390, 393, 395, 396, 398, 399, 400, 402, 403, 404, 405, 406, 407, 409, 410, 411, 412, 413, 414, 415, 416, 417, 418, 419, 420, 421, 422, 423, 424, 425, 426, 428, 429, 430, 431, 432, 433, 434, 435, 436, 437, 438, 439, 441, 442, 444, 445, 446, 448, 449, 451, 452, 453, 454, 455, 456, 457, 458, 459, 460, 461, 462, 464, 465, 466, 467, 468, 469, 470, 471, 473, 474, 475, 476, 477, 479, 480, 481, 483, 484, 485, 487, 489, 490, 491, 492, 493, 494, 495, 499, 500, 501, 503, 504, 505, 506, 508, 509, 510, 511, 512, 513, 514, 515, 516, 517, 518, 519, 520, 522, 524, 525, 526, 527, 528, 529, 530, 532, 534, 535, 537, 538, 539, 541}
# Processing T2 image for patient 491
# Processing T2 image for patient 121
# Processing T2 image for patient 93
# Processing T2 image for patient 183
# Processing T2 image for patient 421
# Processing T2 image for patient 295
# Processing T2 image for patient 355
# Processing T2 image for patient 390
# Processing T2 image for patient 145
# Processing T2 image for patient 197
# Processing T2 image for patient 173
# Processing T2 image for patient 108
# Processing T2 image for patient 325
# Processing T2 image for patient 191
# Processing T2 image for patient 367
# Processing T2 image for patient 453
# Processing T2 image for patient 234
# Processing T2 image for patient 412
# Processing T2 image for patient 370
# Processing T2 image for patient 381
# Processing T2 image for patient 510
# Processing T2 image for patient 71
# Processing T2 image for patient 112
# Processing T2 image for patient 330
# Processing T2 image for patient 264
# Processing T2 image for patient 276
# Processing T2 image for patient 179
# Processing T2 image for patient 374
# Processing T2 image for patient 131
# Processing T2 image for patient 223
# Processing T2 image for patient 208
# Processing T2 image for patient 23
# Processing T2 image for patient 229
# Processing T2 image for patient 156
# Processing T2 image for patient 198
# Processing T2 image for patient 18
# Processing T2 image for patient 539
# Processing T2 image for patient 205
# Processing T2 image for patient 236
# Processing T2 image for patient 26
# Processing T2 image for patient 103
# Processing T2 image for patient 279
# Processing T2 image for patient 372
# Processing T2 image for patient 69
# Processing T2 image for patient 474
# Processing T2 image for patient 237
# Processing T2 image for patient 250
# Processing T2 image for patient 31
# Processing T2 image for patient 454
# Processing T2 image for patient 534
# Processing T2 image for patient 142
# Processing T2 image for patient 516
# Processing T2 image for patient 45
# Processing T2 image for patient 298
# Processing T2 image for patient 240
# Processing T2 image for patient 123
# Processing T2 image for patient 382
# Processing T2 image for patient 525
# Processing T2 image for patient 306
# Processing T2 image for patient 102
# Processing T2 image for patient 422
# Processing T2 image for patient 86
# Processing T2 image for patient 166
# Processing T2 image for patient 297
# Processing T2 image for patient 243
# Processing T2 image for patient 464
# Processing T2 image for patient 375
# Processing T2 image for patient 426
# Processing T2 image for patient 358
# Processing T2 image for patient 104
# Processing T2 image for patient 448
# Processing T2 image for patient 8
# Processing T2 image for patient 66
# Processing T2 image for patient 270
# Processing T2 image for patient 128
# Processing T2 image for patient 541
# Processing T2 image for patient 457
# Processing T2 image for patient 538
# Processing T2 image for patient 75
# Processing T2 image for patient 456
# Processing T2 image for patient 353
# Processing T2 image for patient 13
# Processing T2 image for patient 99
# Processing T2 image for patient 481
# Processing T2 image for patient 465
# Processing T2 image for patient 160
# Processing T2 image for patient 495
# Processing T2 image for patient 251
# Processing T2 image for patient 455
# Processing T2 image for patient 24
# Processing T2 image for patient 509
# Processing T2 image for patient 494
# Processing T2 image for patient 530
# Processing T2 image for patient 405
# Processing T2 image for patient 524
# Processing T2 image for patient 176
# Processing T2 image for patient 116
# Processing T2 image for patient 68
# Processing T2 image for patient 137
# Processing T2 image for patient 537
# Processing T2 image for patient 88
# Processing T2 image for patient 12
# Processing T2 image for patient 190
# Processing T2 image for patient 20
# Processing T2 image for patient 480
# Processing T2 image for patient 307
# Processing T2 image for patient 468
# Processing T2 image for patient 458
# Processing T2 image for patient 119
# Processing T2 image for patient 186
# Processing T2 image for patient 30
# Processing T2 image for patient 70
# Processing T2 image for patient 135
# Processing T2 image for patient 407
# Processing T2 image for patient 346
# Processing T2 image for patient 461
# Processing T2 image for patient 238
# Processing T2 image for patient 201
# Processing T2 image for patient 423
# Processing T2 image for patient 506
# Processing T2 image for patient 106
# Processing T2 image for patient 514
# Processing T2 image for patient 532
# Processing T2 image for patient 126
# Processing T2 image for patient 356
# Processing T2 image for patient 433
# Processing T2 image for patient 338
# Processing T2 image for patient 368
# Processing T2 image for patient 228
# Processing T2 image for patient 384
# Processing T2 image for patient 78
# Processing T2 image for patient 489
# Processing T2 image for patient 310
# Processing T2 image for patient 520
# Processing T2 image for patient 527
# Processing T2 image for patient 287
# Processing T2 image for patient 233
# Processing T2 image for patient 389
# Processing T2 image for patient 467
# Processing T2 image for patient 436
# Processing T2 image for patient 35
# Processing T2 image for patient 29
# Processing T2 image for patient 515
# Processing T2 image for patient 273
# Processing T2 image for patient 65
# Processing T2 image for patient 318
# Processing T2 image for patient 154
# Processing T2 image for patient 449
# Processing T2 image for patient 151
# Processing T2 image for patient 95
# Processing T2 image for patient 227
# Processing T2 image for patient 111
# Processing T2 image for patient 272
# Processing T2 image for patient 141
# Processing T2 image for patient 362
# Processing T2 image for patient 476
# Processing T2 image for patient 245
# Processing T2 image for patient 460
# Processing T2 image for patient 247
# Processing T2 image for patient 499
# Processing T2 image for patient 396
# Processing T2 image for patient 83
# Processing T2 image for patient 445
# Processing T2 image for patient 415
# Processing T2 image for patient 58
# Processing T2 image for patient 209
# Processing T2 image for patient 164
# Processing T2 image for patient 371
# Processing T2 image for patient 483
# Processing T2 image for patient 10
# Processing T2 image for patient 77
# Processing T2 image for patient 359
# Processing T2 image for patient 435
# Processing T2 image for patient 477
# Processing T2 image for patient 231
# Processing T2 image for patient 206
# Processing T2 image for patient 89
# Processing T2 image for patient 406
# Processing T2 image for patient 424
# Processing T2 image for patient 517
# Processing T2 image for patient 512
# Processing T2 image for patient 200
# Processing T2 image for patient 261
# Processing T2 image for patient 440
# Could not extract features for patient 440 Reason: Label (1) not present in mask. Choose from [2]
# retrying with label-value=2
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Filters applied on the image:
# 	Original
# 	SquareRoot
# Calculated features:
# Computed diagnostics_Versions_PyRadiomics: v3.0.1
# Computed diagnostics_Versions_Numpy: 1.21.6
# Computed diagnostics_Versions_SimpleITK: 2.2.1
# Computed diagnostics_Versions_PyWavelet: 1.3.0
# Computed diagnostics_Versions_Python: 3.7.0
# Computed diagnostics_Configuration_Settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': None, 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 2, 'additionalInfo': True}
# Computed diagnostics_Configuration_EnabledImageTypes: {'Original': {}, 'SquareRoot': {}}
# Computed diagnostics_Image-original_Hash: b6170b05545b4a3dcc9b3f456381ec34ab305323
# Computed diagnostics_Image-original_Dimensionality: 3D
# Computed diagnostics_Image-original_Spacing: (1.0, 1.0, 1.0)
# Computed diagnostics_Image-original_Size: (240, 240, 155)
# Computed diagnostics_Image-original_Mean: 86.46593543574181
# Computed diagnostics_Image-original_Minimum: 0.0
# Computed diagnostics_Image-original_Maximum: 1356.3477783203125
# Computed diagnostics_Mask-original_Hash: 8a6caa6d7e72516b16957a57d619a0d249719714
# Computed diagnostics_Mask-original_Spacing: (1.0, 1.0, 1.0)
# Computed diagnostics_Mask-original_Size: (240, 240, 155)
# Computed diagnostics_Mask-original_BoundingBox: (50, 33, 41, 79, 148, 75)
# Computed diagnostics_Mask-original_VoxelNum: 261985
# Computed diagnostics_Mask-original_VolumeNum: 2
# Computed diagnostics_Mask-original_CenterOfMassIndex: (87.73580548504685, 119.97307861137088, 80.49262744050232)
# Computed diagnostics_Mask-original_CenterOfMass: (87.73580548504685, -119.02692138862912, 80.49262744050232)
# Computed original_firstorder_10Percentile: 452.7575378417969
# Computed original_firstorder_90Percentile: 825.5850219726562
# Computed original_firstorder_Energy: 117692556036.15186
# Computed original_firstorder_Entropy: 4.48260486182652
# Computed original_firstorder_InterquartileRange: 219.40399169921875
# Computed original_firstorder_Kurtosis: 2.402919685645469
# Computed original_firstorder_Maximum: 1145.760498046875
# Computed original_firstorder_MeanAbsoluteDeviation: 118.8360773279129
# Computed original_firstorder_Mean: 655.0579096510066
# Computed original_firstorder_Median: 677.8117065429688
# Computed original_firstorder_Minimum: 62.60703659057617
# Computed original_firstorder_Range: 1083.1534614562988
# Computed original_firstorder_RobustMeanAbsoluteDeviation: 89.15981181675471
# Computed original_firstorder_RootMeanSquared: 670.2491690755718
# Computed original_firstorder_Skewness: -0.2278902286362491
# Computed original_firstorder_TotalEnergy: 117692556036.15186
# Computed original_firstorder_Uniformity: 0.050588351175016845
# Computed original_firstorder_Variance: 20133.083650147986
# Computed squareroot_firstorder_10Percentile: 783.6432099938696
# Computed squareroot_firstorder_90Percentile: 1058.1967729903256
# Computed squareroot_firstorder_Energy: 232770093896.5818
# Computed squareroot_firstorder_Entropy: 4.029457645285264
# Computed squareroot_firstorder_InterquartileRange: 158.83164302053638
# Computed squareroot_firstorder_Kurtosis: 2.600674909698411
# Computed squareroot_firstorder_Maximum: 1246.6152999273888
# Computed squareroot_firstorder_MeanAbsoluteDeviation: 87.7026312441153
# Computed squareroot_firstorder_Mean: 936.7028644065041
# Computed squareroot_firstorder_Median: 958.8265757106732
# Computed squareroot_firstorder_Minimum: 291.405070283354
# Computed squareroot_firstorder_Range: 955.2102296440348
# Computed squareroot_firstorder_RobustMeanAbsoluteDeviation: 65.00498851871865
# Computed squareroot_firstorder_RootMeanSquared: 942.5955338459285
# Computed squareroot_firstorder_Skewness: -0.4635468244387265
# Computed squareroot_firstorder_TotalEnergy: 232770093896.5818
# Computed squareroot_firstorder_Uniformity: 0.07088713553895067
# Computed squareroot_firstorder_Variance: 11074.084238941126
# Findme {'squareroot_firstorder_10Percentile': array(783.64320999), 'squareroot_firstorder_90Percentile': array(1058.19677299), 'squareroot_firstorder_Energy': array(2.32770094e+11), 'squareroot_firstorder_Entropy': array(4.02945765), 'squareroot_firstorder_InterquartileRange': array(158.83164302), 'squareroot_firstorder_Kurtosis': array(2.60067491), 'squareroot_firstorder_Maximum': array(1246.61529993), 'squareroot_firstorder_MeanAbsoluteDeviation': array(87.70263124), 'squareroot_firstorder_Mean': array(936.70286441), 'squareroot_firstorder_Median': array(958.82657571), 'squareroot_firstorder_Minimum': array(291.40507028), 'squareroot_firstorder_Range': array(955.21022964), 'squareroot_firstorder_RobustMeanAbsoluteDeviation': array(65.00498852), 'squareroot_firstorder_RootMeanSquared': array(942.59553385), 'squareroot_firstorder_Skewness': array(-0.46354682), 'squareroot_firstorder_TotalEnergy': array(2.32770094e+11), 'squareroot_firstorder_Uniformity': array(0.07088714), 'squareroot_firstorder_Variance': array(11074.08423894)}
# Processing T2 image for patient 118
# Processing T2 image for patient 282
# Processing T2 image for patient 252
# Processing T2 image for patient 409
# Processing T2 image for patient 490
# Processing T2 image for patient 378
# Processing T2 image for patient 402
# Processing T2 image for patient 357
# Processing T2 image for patient 134
# Processing T2 image for patient 300
# Processing T2 image for patient 91
# Processing T2 image for patient 416
# Processing T2 image for patient 452
# Processing T2 image for patient 475
# Processing T2 image for patient 469
# Processing T2 image for patient 246
# Processing T2 image for patient 347
# Processing T2 image for patient 39
# Processing T2 image for patient 290
# Processing T2 image for patient 174
# Processing T2 image for patient 403
# Processing T2 image for patient 11
# Processing T2 image for patient 528
# Processing T2 image for patient 471
# Processing T2 image for patient 441
# Processing T2 image for patient 364
# Processing T2 image for patient 16
# Processing T2 image for patient 105
# Processing T2 image for patient 479
# Processing T2 image for patient 312
# Processing T2 image for patient 178
# Processing T2 image for patient 127
# Processing T2 image for patient 340
# Processing T2 image for patient 94
# Processing T2 image for patient 425
# Processing T2 image for patient 444
# Processing T2 image for patient 388
# Processing T2 image for patient 529
# Processing T2 image for patient 286
# Processing T2 image for patient 484
# Processing T2 image for patient 349
# Processing T2 image for patient 418
# Processing T2 image for patient 373
# Processing T2 image for patient 526
# Processing T2 image for patient 383
# Processing T2 image for patient 87
# Processing T2 image for patient 314
# Processing T2 image for patient 265
# Processing T2 image for patient 225
# Processing T2 image for patient 4
# Processing T2 image for patient 420
# Processing T2 image for patient 387
# Processing T2 image for patient 399
# Processing T2 image for patient 508
# Processing T2 image for patient 253
# Processing T2 image for patient 284
# Processing T2 image for patient 432
# Processing T2 image for patient 187
# Processing T2 image for patient 336
# Processing T2 image for patient 319
# Processing T2 image for patient 513
# Processing T2 image for patient 158
# Processing T2 image for patient 302
# Processing T2 image for patient 14
# Processing T2 image for patient 274
# Processing T2 image for patient 132
# Processing T2 image for patient 148
# Processing T2 image for patient 27
# Processing T2 image for patient 400
# Processing T2 image for patient 281
# Processing T2 image for patient 331
# Processing T2 image for patient 451
# Processing T2 image for patient 501
# Processing T2 image for patient 266
# Processing T2 image for patient 96
# Processing T2 image for patient 144
# Processing T2 image for patient 64
# Processing T2 image for patient 332
# Processing T2 image for patient 344
# Processing T2 image for patient 462
# Processing T2 image for patient 67
# Processing T2 image for patient 419
# Processing T2 image for patient 518
# Processing T2 image for patient 43
# Processing T2 image for patient 360
# Processing T2 image for patient 169
# Processing T2 image for patient 260
# Processing T2 image for patient 323
# Processing T2 image for patient 317
# Processing T2 image for patient 79
# Processing T2 image for patient 334
# Processing T2 image for patient 350
# Processing T2 image for patient 232
# Processing T2 image for patient 74
# Processing T2 image for patient 268
# Processing T2 image for patient 466
# Processing T2 image for patient 48
# Processing T2 image for patient 170
# Processing T2 image for patient 188
# Processing T2 image for patient 55
# Processing T2 image for patient 84
# Processing T2 image for patient 42
# Processing T2 image for patient 165
# Processing T2 image for patient 288
# Processing T2 image for patient 114
# Processing T2 image for patient 207
# Processing T2 image for patient 411
# Processing T2 image for patient 380
# Processing T2 image for patient 21
# Processing T2 image for patient 500
# Processing T2 image for patient 214
# Processing T2 image for patient 184
# Processing T2 image for patient 430
# Processing T2 image for patient 157
# Processing T2 image for patient 143
# Processing T2 image for patient 379
# Processing T2 image for patient 485
# Processing T2 image for patient 256
# Processing T2 image for patient 459
# Processing T2 image for patient 414
# Processing T2 image for patient 413
# Processing T2 image for patient 470
# Processing T2 image for patient 434
# Processing T2 image for patient 337
# Processing T2 image for patient 107
# Processing T2 image for patient 308
# Processing T2 image for patient 329
# Processing T2 image for patient 519
# Processing T2 image for patient 277
# Processing T2 image for patient 446
# Processing T2 image for patient 44
# Processing T2 image for patient 189
# Processing T2 image for patient 167
# Processing T2 image for patient 22
# Processing T2 image for patient 428
# Processing T2 image for patient 493
# Processing T2 image for patient 140
# Processing T2 image for patient 101
# Processing T2 image for patient 386
# Processing T2 image for patient 377
# Processing T2 image for patient 80
# Processing T2 image for patient 438
# Processing T2 image for patient 213
# Processing T2 image for patient 168
# Processing T2 image for patient 258
# Processing T2 image for patient 473
# Processing T2 image for patient 431
# Processing T2 image for patient 429
# Processing T2 image for patient 535
# Processing T2 image for patient 242
# Processing T2 image for patient 63
# Processing T2 image for patient 303
# Processing T2 image for patient 82
# Processing T2 image for patient 352
# Processing T2 image for patient 196
# Processing T2 image for patient 505
# Processing T2 image for patient 385
# Processing T2 image for patient 32
# Processing T2 image for patient 326
# Processing T2 image for patient 522
# Processing T2 image for patient 417
# Processing T2 image for patient 404
# Processing T2 image for patient 442
# Processing T2 image for patient 503
# Processing T2 image for patient 147
# Processing T2 image for patient 342
# Processing T2 image for patient 90
# Processing T2 image for patient 365
# Processing T2 image for patient 136
# Processing T2 image for patient 25
# Processing T2 image for patient 162
# Processing T2 image for patient 410
# Processing T2 image for patient 163
# Processing T2 image for patient 305
# Processing T2 image for patient 283
# Processing T2 image for patient 59
# Processing T2 image for patient 439
# Processing T2 image for patient 398
# Processing T2 image for patient 487
# Processing T2 image for patient 348
# Processing T2 image for patient 202
# Processing T2 image for patient 7
# Processing T2 image for patient 269
# Processing T2 image for patient 150
# Processing T2 image for patient 511
# Processing T2 image for patient 37
# Processing T2 image for patient 309
# Processing T2 image for patient 393
# Processing T2 image for patient 180
# Processing T2 image for patient 53
# Processing T2 image for patient 296
# Processing T2 image for patient 354
# Processing T2 image for patient 5
# Processing T2 image for patient 437
# Processing T2 image for patient 36
# Processing T2 image for patient 341
# Processing T2 image for patient 321
# Processing T2 image for patient 395
# Processing T2 image for patient 85
# Processing T2 image for patient 204
# Processing T2 image for patient 122
# Processing T2 image for patient 210
# Processing T2 image for patient 15
# Processing T2 image for patient 129
# Processing T2 image for patient 504
# Processing T2 image for patient 327
# Processing T2 image for patient 492
# Processing T2 image for patient 57
# Processing T2 image for patient 130
# Processing T2 image for patient 172
# Processing T2 image for patient 159
# Processing T2 image for patient 235
# Number of errors occurred: 395 --> patients affected by error {4, 5, 7, 8, 10, 11, 12, 13, 14, 15, 16, 18, 20, 21, 22, 23, 24, 25, 26, 27, 29, 30, 31, 32, 35, 36, 37, 39, 42, 43, 44, 45, 48, 53, 55, 57, 58, 59, 63, 64, 65, 66, 67, 68, 69, 70, 71, 74, 75, 77, 78, 79, 80, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 93, 94, 95, 96, 99, 101, 102, 103, 104, 105, 106, 107, 108, 111, 112, 114, 116, 118, 119, 121, 122, 123, 126, 127, 128, 129, 130, 131, 132, 134, 135, 136, 137, 140, 141, 142, 143, 144, 145, 147, 148, 150, 151, 154, 156, 157, 158, 159, 160, 162, 163, 164, 165, 166, 167, 168, 169, 170, 172, 173, 174, 176, 178, 179, 180, 183, 184, 186, 187, 188, 189, 190, 191, 196, 197, 198, 200, 201, 202, 204, 205, 206, 207, 208, 209, 210, 213, 214, 223, 225, 227, 228, 229, 231, 232, 233, 234, 235, 236, 237, 238, 240, 242, 243, 245, 246, 247, 250, 251, 252, 253, 256, 258, 260, 261, 264, 265, 266, 268, 269, 270, 272, 273, 274, 276, 277, 279, 281, 282, 283, 284, 286, 287, 288, 290, 295, 296, 297, 298, 300, 302, 303, 305, 306, 307, 308, 309, 310, 312, 314, 317, 318, 319, 321, 323, 325, 326, 327, 329, 330, 331, 332, 334, 336, 337, 338, 340, 341, 342, 344, 346, 347, 348, 349, 350, 352, 353, 354, 355, 356, 357, 358, 359, 360, 362, 364, 365, 367, 368, 370, 371, 372, 373, 374, 375, 377, 378, 379, 380, 381, 382, 383, 384, 385, 386, 387, 388, 389, 390, 393, 395, 396, 398, 399, 400, 402, 403, 404, 405, 406, 407, 409, 410, 411, 412, 413, 414, 415, 416, 417, 418, 419, 420, 421, 422, 423, 424, 425, 426, 428, 429, 430, 431, 432, 433, 434, 435, 436, 437, 438, 439, 441, 442, 444, 445, 446, 448, 449, 451, 452, 453, 454, 455, 456, 457, 458, 459, 460, 461, 462, 464, 465, 466, 467, 468, 469, 470, 471, 473, 474, 475, 476, 477, 479, 480, 481, 483, 484, 485, 487, 489, 490, 491, 492, 493, 494, 495, 499, 500, 501, 503, 504, 505, 506, 508, 509, 510, 511, 512, 513, 514, 515, 516, 517, 518, 519, 520, 522, 524, 525, 526, 527, 528, 529, 530, 532, 534, 535, 537, 538, 539, 541}
# Processing DTI_eddy_FA image for patient 491
# Processing DTI_eddy_FA image for patient 121
# Processing DTI_eddy_FA image for patient 93
# Processing DTI_eddy_FA image for patient 183
# Processing DTI_eddy_FA image for patient 421
# Processing DTI_eddy_FA image for patient 295
# Processing DTI_eddy_FA image for patient 355
# Processing DTI_eddy_FA image for patient 390
# Processing DTI_eddy_FA image for patient 145
# Processing DTI_eddy_FA image for patient 197
# Processing DTI_eddy_FA image for patient 173
# Processing DTI_eddy_FA image for patient 108
# Processing DTI_eddy_FA image for patient 325
# Processing DTI_eddy_FA image for patient 191
# Processing DTI_eddy_FA image for patient 367
# Processing DTI_eddy_FA image for patient 453
# Processing DTI_eddy_FA image for patient 234
# Processing DTI_eddy_FA image for patient 412
# Processing DTI_eddy_FA image for patient 370
# Processing DTI_eddy_FA image for patient 381
# Processing DTI_eddy_FA image for patient 510
# Processing DTI_eddy_FA image for patient 71
# Processing DTI_eddy_FA image for patient 112
# Processing DTI_eddy_FA image for patient 330
# Processing DTI_eddy_FA image for patient 264
# Processing DTI_eddy_FA image for patient 276
# Processing DTI_eddy_FA image for patient 179
# Processing DTI_eddy_FA image for patient 374
# Processing DTI_eddy_FA image for patient 131
# Processing DTI_eddy_FA image for patient 223
# Processing DTI_eddy_FA image for patient 208
# Processing DTI_eddy_FA image for patient 23
# Processing DTI_eddy_FA image for patient 229
# Processing DTI_eddy_FA image for patient 156
# Processing DTI_eddy_FA image for patient 198
# Processing DTI_eddy_FA image for patient 18
# Processing DTI_eddy_FA image for patient 539
# Processing DTI_eddy_FA image for patient 205
# Processing DTI_eddy_FA image for patient 236
# Processing DTI_eddy_FA image for patient 26
# Processing DTI_eddy_FA image for patient 103
# Processing DTI_eddy_FA image for patient 279
# Processing DTI_eddy_FA image for patient 372
# Processing DTI_eddy_FA image for patient 69
# Processing DTI_eddy_FA image for patient 474
# Processing DTI_eddy_FA image for patient 237
# Processing DTI_eddy_FA image for patient 250
# Processing DTI_eddy_FA image for patient 31
# Processing DTI_eddy_FA image for patient 454
# Processing DTI_eddy_FA image for patient 534
# Processing DTI_eddy_FA image for patient 142
# Processing DTI_eddy_FA image for patient 516
# Processing DTI_eddy_FA image for patient 45
# Processing DTI_eddy_FA image for patient 298
# Processing DTI_eddy_FA image for patient 240
# Processing DTI_eddy_FA image for patient 123
# Processing DTI_eddy_FA image for patient 382
# Processing DTI_eddy_FA image for patient 525
# Processing DTI_eddy_FA image for patient 306
# Processing DTI_eddy_FA image for patient 102
# Processing DTI_eddy_FA image for patient 422
# Processing DTI_eddy_FA image for patient 86
# Processing DTI_eddy_FA image for patient 166
# Processing DTI_eddy_FA image for patient 297
# Processing DTI_eddy_FA image for patient 243
# Processing DTI_eddy_FA image for patient 464
# Processing DTI_eddy_FA image for patient 375
# Processing DTI_eddy_FA image for patient 426
# Processing DTI_eddy_FA image for patient 358
# Processing DTI_eddy_FA image for patient 104
# Processing DTI_eddy_FA image for patient 448
# Processing DTI_eddy_FA image for patient 8
# Processing DTI_eddy_FA image for patient 66
# Processing DTI_eddy_FA image for patient 270
# Processing DTI_eddy_FA image for patient 128
# Processing DTI_eddy_FA image for patient 541
# Processing DTI_eddy_FA image for patient 457
# Processing DTI_eddy_FA image for patient 538
# Processing DTI_eddy_FA image for patient 75
# Processing DTI_eddy_FA image for patient 456
# Processing DTI_eddy_FA image for patient 353
# Processing DTI_eddy_FA image for patient 13
# Processing DTI_eddy_FA image for patient 99
# Processing DTI_eddy_FA image for patient 481
# Processing DTI_eddy_FA image for patient 465
# Processing DTI_eddy_FA image for patient 160
# Processing DTI_eddy_FA image for patient 495
# Processing DTI_eddy_FA image for patient 251
# Processing DTI_eddy_FA image for patient 455
# Processing DTI_eddy_FA image for patient 24
# Processing DTI_eddy_FA image for patient 509
# Processing DTI_eddy_FA image for patient 494
# Processing DTI_eddy_FA image for patient 530
# Processing DTI_eddy_FA image for patient 405
# Processing DTI_eddy_FA image for patient 524
# Processing DTI_eddy_FA image for patient 176
# Processing DTI_eddy_FA image for patient 116
# Processing DTI_eddy_FA image for patient 68
# Processing DTI_eddy_FA image for patient 137
# Processing DTI_eddy_FA image for patient 537
# Processing DTI_eddy_FA image for patient 88
# Processing DTI_eddy_FA image for patient 12
# Processing DTI_eddy_FA image for patient 190
# Processing DTI_eddy_FA image for patient 20
# Processing DTI_eddy_FA image for patient 480
# Processing DTI_eddy_FA image for patient 307
# Processing DTI_eddy_FA image for patient 468
# Processing DTI_eddy_FA image for patient 458
# Processing DTI_eddy_FA image for patient 119
# Processing DTI_eddy_FA image for patient 186
# Processing DTI_eddy_FA image for patient 30
# Processing DTI_eddy_FA image for patient 70
# Processing DTI_eddy_FA image for patient 135
# Processing DTI_eddy_FA image for patient 407
# Processing DTI_eddy_FA image for patient 346
# ...
# Computed original_firstorder_InterquartileRange: 186.7313232421875
# Computed original_firstorder_Kurtosis: 7.015835510352738
# Computed original_firstorder_Maximum: 1918.9429931640625
# Computed original_firstorder_MeanAbsoluteDeviation: 113.32725389929826
# Computed original_firstorder_Mean: 691.4588400789596
# Computed original_firstorder_Median: 690.090087890625
# Computed original_firstorder_Minimum: 82.86316680908203
# Computed original_firstorder_Range: 1836.0798263549805
# Computed original_firstorder_RobustMeanAbsoluteDeviation: 76.81313845935382
# Computed original_firstorder_RootMeanSquared: 707.5972665824484
# Computed original_firstorder_Skewness: 0.804116061326319
# Computed original_firstorder_TotalEnergy: 131174289210.46243
# Computed original_firstorder_Uniformity: 0.05154919069460247
# Computed original_firstorder_Variance: 22578.564151612372
# Computed squareroot_firstorder_10Percentile: 1014.4504913059693
# Computed squareroot_firstorder_90Percentile: 1309.0778850682643
# Computed squareroot_firstorder_Energy: 361401113524.8437
# Computed squareroot_firstorder_Entropy: 4.33867215839906
# Computed squareroot_firstorder_InterquartileRange: 159.54071908725768
# Computed squareroot_firstorder_Kurtosis: 5.206623941051736
# Computed squareroot_firstorder_Maximum: 1956.610590480923
# Computed squareroot_firstorder_MeanAbsoluteDeviation: 96.97671663560118
# Computed squareroot_firstorder_Mean: 1167.6315767975318
# Computed squareroot_firstorder_Median: 1173.3464347035888
# Computed squareroot_firstorder_Minimum: 406.5875974045725
# Computed squareroot_firstorder_Range: 1550.0229930763505
# Computed squareroot_firstorder_RobustMeanAbsoluteDeviation: 65.75397551657976
# Computed squareroot_firstorder_RootMeanSquared: 1174.5094893220096
# Computed squareroot_firstorder_Skewness: 0.09668727475596317
# Computed squareroot_firstorder_TotalEnergy: 361401113524.8437
# Computed squareroot_firstorder_Uniformity: 0.06033683525070336
# Computed squareroot_firstorder_Variance: 16109.041372757429
# Findme {'squareroot_firstorder_10Percentile': array(1014.45049131), 'squareroot_firstorder_90Percentile': array(1309.07788507), 'squareroot_firstorder_Energy': array(3.61401114e+11), 'squareroot_firstorder_Entropy': array(4.33867216), 'squareroot_firstorder_InterquartileRange': array(159.54071909), 'squareroot_firstorder_Kurtosis': array(5.20662394), 'squareroot_firstorder_Maximum': array(1956.61059048), 'squareroot_firstorder_MeanAbsoluteDeviation': array(96.97671664), 'squareroot_firstorder_Mean': array(1167.6315768), 'squareroot_firstorder_Median': array(1173.3464347), 'squareroot_firstorder_Minimum': array(406.5875974), 'squareroot_firstorder_Range': array(1550.02299308), 'squareroot_firstorder_RobustMeanAbsoluteDeviation': array(65.75397552), 'squareroot_firstorder_RootMeanSquared': array(1174.50948932), 'squareroot_firstorder_Skewness': array(0.09668727), 'squareroot_firstorder_TotalEnergy': array(3.61401114e+11), 'squareroot_firstorder_Uniformity': array(0.06033684), 'squareroot_firstorder_Variance': array(16109.04137276)}
# Processing DWI image for patient 118
# Processing DWI image for patient 282
# Processing DWI image for patient 252
# Processing DWI image for patient 409
# Processing DWI image for patient 490
# Processing DWI image for patient 378
# Processing DWI image for patient 402
# Processing DWI image for patient 357
# Processing DWI image for patient 134
# Processing DWI image for patient 300
# Processing DWI image for patient 91
# Processing DWI image for patient 416
# Processing DWI image for patient 452
# Processing DWI image for patient 475
# Processing DWI image for patient 469
# Processing DWI image for patient 246
# Processing DWI image for patient 347
# Processing DWI image for patient 39
# Processing DWI image for patient 290
# Processing DWI image for patient 174
# Processing DWI image for patient 403
# Processing DWI image for patient 11
# Processing DWI image for patient 528
# Processing DWI image for patient 471
# Processing DWI image for patient 441
# Processing DWI image for patient 364
# Processing DWI image for patient 16
# Processing DWI image for patient 105
# Processing DWI image for patient 479
# Processing DWI image for patient 312
# Processing DWI image for patient 178
# Processing DWI image for patient 127
# Processing DWI image for patient 340
# Processing DWI image for patient 94
# Processing DWI image for patient 425
# Processing DWI image for patient 444
# Processing DWI image for patient 388
# Processing DWI image for patient 529
# Processing DWI image for patient 286
# Processing DWI image for patient 484
# Processing DWI image for patient 349
# Processing DWI image for patient 418
# Processing DWI image for patient 373
# Processing DWI image for patient 526
# Processing DWI image for patient 383
# Processing DWI image for patient 87
# Processing DWI image for patient 314
# Processing DWI image for patient 265
# Processing DWI image for patient 225
# Processing DWI image for patient 4
# Processing DWI image for patient 420
# Processing DWI image for patient 387
# Processing DWI image for patient 399
# Processing DWI image for patient 508
# Processing DWI image for patient 253
# Processing DWI image for patient 284
# Processing DWI image for patient 432
# Processing DWI image for patient 187
# Processing DWI image for patient 336
# Processing DWI image for patient 319
# Processing DWI image for patient 513
# Processing DWI image for patient 158
# Processing DWI image for patient 302
# Processing DWI image for patient 14
# Processing DWI image for patient 274
# Processing DWI image for patient 132
# Processing DWI image for patient 148
# Processing DWI image for patient 27
# Processing DWI image for patient 400
# Processing DWI image for patient 281
# Processing DWI image for patient 331
# Processing DWI image for patient 451
# Processing DWI image for patient 501
# Processing DWI image for patient 266
# Processing DWI image for patient 96
# Processing DWI image for patient 144
# Processing DWI image for patient 64
# Processing DWI image for patient 332
# Processing DWI image for patient 344
# Processing DWI image for patient 462
# Processing DWI image for patient 67
# Processing DWI image for patient 419
# Processing DWI image for patient 518
# Processing DWI image for patient 43
# Processing DWI image for patient 360
# Processing DWI image for patient 169
# Processing DWI image for patient 260
# Processing DWI image for patient 323
# Processing DWI image for patient 317
# Processing DWI image for patient 79
# Processing DWI image for patient 334
# Processing DWI image for patient 350
# Processing DWI image for patient 232
# Processing DWI image for patient 74
# Processing DWI image for patient 268
# Processing DWI image for patient 466
# Processing DWI image for patient 48
# Processing DWI image for patient 170
# Processing DWI image for patient 188
# Processing DWI image for patient 55
# Processing DWI image for patient 84
# Processing DWI image for patient 42
# Processing DWI image for patient 165
# Processing DWI image for patient 288
# Processing DWI image for patient 114
# Processing DWI image for patient 207
# Processing DWI image for patient 411
# Processing DWI image for patient 380
# Processing DWI image for patient 21
# Processing DWI image for patient 500
# Processing DWI image for patient 214
# Processing DWI image for patient 184
# Processing DWI image for patient 430
# Processing DWI image for patient 157
# Processing DWI image for patient 143
# Processing DWI image for patient 379
# Processing DWI image for patient 485
# Processing DWI image for patient 256
# Processing DWI image for patient 459
# Processing DWI image for patient 414
# Processing DWI image for patient 413
# Processing DWI image for patient 470
# Processing DWI image for patient 434
# Processing DWI image for patient 337
# Processing DWI image for patient 107
# Processing DWI image for patient 308
# Processing DWI image for patient 329
# Processing DWI image for patient 519
# Processing DWI image for patient 277
# Processing DWI image for patient 446
# Processing DWI image for patient 44
# Processing DWI image for patient 189
# Processing DWI image for patient 167
# Processing DWI image for patient 22
# Processing DWI image for patient 428
# Processing DWI image for patient 493
# Processing DWI image for patient 140
# Processing DWI image for patient 101
# Processing DWI image for patient 386
# Processing DWI image for patient 377
# Processing DWI image for patient 80
# Processing DWI image for patient 438
# Processing DWI image for patient 213
# Processing DWI image for patient 168
# Processing DWI image for patient 258
# Processing DWI image for patient 473
# Processing DWI image for patient 431
# Processing DWI image for patient 429
# Processing DWI image for patient 535
# Processing DWI image for patient 242
# Processing DWI image for patient 63
# Processing DWI image for patient 303
# Processing DWI image for patient 82
# Processing DWI image for patient 352
# Processing DWI image for patient 196
# Processing DWI image for patient 505
# Processing DWI image for patient 385
# Processing DWI image for patient 32
# Processing DWI image for patient 326
# Processing DWI image for patient 522
# Processing DWI image for patient 417
# Processing DWI image for patient 404
# Processing DWI image for patient 442
# Processing DWI image for patient 503
# Processing DWI image for patient 147
# Processing DWI image for patient 342
# Processing DWI image for patient 90
# Processing DWI image for patient 365
# Processing DWI image for patient 136
# Processing DWI image for patient 25
# Processing DWI image for patient 162
# Processing DWI image for patient 410
# Processing DWI image for patient 163
# Processing DWI image for patient 305
# Processing DWI image for patient 283
# Processing DWI image for patient 59
# Processing DWI image for patient 439
# Processing DWI image for patient 398
# Processing DWI image for patient 487
# Processing DWI image for patient 348
# Processing DWI image for patient 202
# Processing DWI image for patient 7
# Processing DWI image for patient 269
# Processing DWI image for patient 150
# Processing DWI image for patient 511
# Processing DWI image for patient 37
# Processing DWI image for patient 309
# Processing DWI image for patient 393
# Processing DWI image for patient 180
# Processing DWI image for patient 53
# Processing DWI image for patient 296
# Processing DWI image for patient 354
# Processing DWI image for patient 5
# Processing DWI image for patient 437
# Processing DWI image for patient 36
# Processing DWI image for patient 341
# Processing DWI image for patient 321
# Processing DWI image for patient 395
# Processing DWI image for patient 85
# Processing DWI image for patient 204
# Processing DWI image for patient 122
# Processing DWI image for patient 210
# Processing DWI image for patient 15
# Processing DWI image for patient 129
# Processing DWI image for patient 504
# Processing DWI image for patient 327
# Processing DWI image for patient 492
# Processing DWI image for patient 57
# Processing DWI image for patient 130
# Processing DWI image for patient 172
# Processing DWI image for patient 159
# Processing DWI image for patient 235
# Number of errors occurred: 395 --> patients affected by error {4, 5, 7, 8, 10, 11, 12, 13, 14, 15, 16, 18, 20, 21, 22, 23, 24, 25, 26, 27, 29, 30, 31, 32, 35, 36, 37, 39, 42, 43, 44, 45, 48, 53, 55, 57, 58, 59, 63, 64, 65, 66, 67, 68, 69, 70, 71, 74, 75, 77, 78, 79, 80, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 93, 94, 95, 96, 99, 101, 102, 103, 104, 105, 106, 107, 108, 111, 112, 114, 116, 118, 119, 121, 122, 123, 126, 127, 128, 129, 130, 131, 132, 134, 135, 136, 137, 140, 141, 142, 143, 144, 145, 147, 148, 150, 151, 154, 156, 157, 158, 159, 160, 162, 163, 164, 165, 166, 167, 168, 169, 170, 172, 173, 174, 176, 178, 179, 180, 183, 184, 186, 187, 188, 189, 190, 191, 196, 197, 198, 200, 201, 202, 204, 205, 206, 207, 208, 209, 210, 213, 214, 223, 225, 227, 228, 229, 231, 232, 233, 234, 235, 236, 237, 238, 240, 242, 243, 245, 246, 247, 250, 251, 252, 253, 256, 258, 260, 261, 264, 265, 266, 268, 269, 270, 272, 273, 274, 276, 277, 279, 281, 282, 283, 284, 286, 287, 288, 290, 295, 296, 297, 298, 300, 302, 303, 305, 306, 307, 308, 309, 310, 312, 314, 317, 318, 319, 321, 323, 325, 326, 327, 329, 330, 331, 332, 334, 336, 337, 338, 340, 341, 342, 344, 346, 347, 348, 349, 350, 352, 353, 354, 355, 356, 357, 358, 359, 360, 362, 364, 365, 367, 368, 370, 371, 372, 373, 374, 375, 377, 378, 379, 380, 381, 382, 383, 384, 385, 386, 387, 388, 389, 390, 393, 395, 396, 398, 399, 400, 402, 403, 404, 405, 406, 407, 409, 410, 411, 412, 413, 414, 415, 416, 417, 418, 419, 420, 421, 422, 423, 424, 425, 426, 428, 429, 430, 431, 432, 433, 434, 435, 436, 437, 438, 439, 441, 442, 444, 445, 446, 448, 449, 451, 452, 453, 454, 455, 456, 457, 458, 459, 460, 461, 462, 464, 465, 466, 467, 468, 469, 470, 471, 473, 474, 475, 476, 477, 479, 480, 481, 483, 484, 485, 487, 489, 490, 491, 492, 493, 494, 495, 499, 500, 501, 503, 504, 505, 506, 508, 509, 510, 511, 512, 513, 514, 515, 516, 517, 518, 519, 520, 522, 524, 525, 526, 527, 528, 529, 530, 532, 534, 535, 537, 538, 539, 541}
# Processing T1_contrast image for patient 491
# Processing T1_contrast image for patient 121
# Processing T1_contrast image for patient 93
# Processing T1_contrast image for patient 183
# Processing T1_contrast image for patient 421
# Processing T1_contrast image for patient 295
# Processing T1_contrast image for patient 355
# Processing T1_contrast image for patient 390
# Processing T1_contrast image for patient 145
# Processing T1_contrast image for patient 197
# Processing T1_contrast image for patient 173
# Processing T1_contrast image for patient 108
# Processing T1_contrast image for patient 325
# Processing T1_contrast image for patient 191
# Processing T1_contrast image for patient 367
# Processing T1_contrast image for patient 453
# Processing T1_contrast image for patient 234
# Processing T1_contrast image for patient 412
# Processing T1_contrast image for patient 370
# Processing T1_contrast image for patient 381
# Processing T1_contrast image for patient 510
# Processing T1_contrast image for patient 71
# Processing T1_contrast image for patient 112
# Processing T1_contrast image for patient 330
# Processing T1_contrast image for patient 264
# Processing T1_contrast image for patient 276
# Processing T1_contrast image for patient 179
# Processing T1_contrast image for patient 374
# Processing T1_contrast image for patient 131
# Processing T1_contrast image for patient 223
# Processing T1_contrast image for patient 208
# Processing T1_contrast image for patient 23
# Processing T1_contrast image for patient 229
# Processing T1_contrast image for patient 156
# Processing T1_contrast image for patient 198
# Processing T1_contrast image for patient 18
# Processing T1_contrast image for patient 539
# Processing T1_contrast image for patient 205
# Processing T1_contrast image for patient 236
# Processing T1_contrast image for patient 26
# Processing T1_contrast image for patient 103
# Processing T1_contrast image for patient 279
# Processing T1_contrast image for patient 372
# Processing T1_contrast image for patient 69
# Processing T1_contrast image for patient 474
# Processing T1_contrast image for patient 237
# Processing T1_contrast image for patient 250
# Processing T1_contrast image for patient 31
# Processing T1_contrast image for patient 454
# Processing T1_contrast image for patient 534
# Processing T1_contrast image for patient 142
# Processing T1_contrast image for patient 516
# Processing T1_contrast image for patient 45
# Processing T1_contrast image for patient 298
# Processing T1_contrast image for patient 240
# Processing T1_contrast image for patient 123
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/cp/h8k252jd0zj9_4h7rrs3cw340000gn/T/ipykernel_12013/2442265007.py in <module>
#     210
#     211 if __name__ == "__main__":
# --> 212     main()
#
# /var/folders/cp/h8k252jd0zj9_4h7rrs3cw340000gn/T/ipykernel_12013/2442265007.py in main()
#     142             patient_id_str = row[0]  # Assuming the patient ID is in the first column
#     143             patient_id = int(patient_id_str.split("-")[-1])
# --> 144             image_path, label_path = fetch_data(base_dir, patient_id, img_type)
#     145
#     146             try:
#
# KeyboardInterrupt:
